# %% [markdown]
# ## 21. Derivatives
#
# 1. Compute derivatives of functions:
#    * $y(x) = -3x+3$
#    * $y(x) = \pi x + \sin(1)$
#    * $y(x) = 4+\sin(2)$
#    * $y(x) = 2x^3 - 3x^2 + 8x - 9$
#    * $y(x) = 6 x^{1/3}$
#    * $y(x) = \sqrt{x}$
#    * $y(x) = \cos(x) + \sin(x)$
#    * $y(x) = 2\sin(x) \cos(x)$
#    * $y(x) = x\sin(x)$
#    * $y(x) = (x+1)(x+1)$
#    * $y(x) = \frac{x}{x+1}$
#    * $y(x) = (x+1)\exp(x)$
#    * $y(x) = \sin(x^2)$
#    * $y(x) = \exp(-2x)$
#    * $y(x) = \frac{1}{\sin(x+1)}$
#    * $y(x) = \sqrt{2x+1}$
#
# 2. Prove:
#    - $\frac{d}{dx} (\ln(\sin(x))) = \cot(x)$
#
# 3. For $f(x) = \cos(x)$, verify that $f''(x) = -f(x)$.
#
# 4. Using de l'Hospital's Rule, find the improper limits:
#    - $\displaystyle \lim_{x\to 0} \frac{\sin{x}}{x}$
#    - $\displaystyle \lim_{x\to \infty} \frac{\ln x}{x}$
#    - $\displaystyle \lim_{x\to \infty} \frac{\exp(x)}{x}$
#
# 5. In physics, the position of a particle is given by $x(t) = 3t^2 - 6t + 1$. Find the velocity $V(t)=x'(t)$ and acceleration $a(t)=V'(t)=x''(t)$ of the particle at time $t = 2$.
#
# ## 22. Extremum
#
# 6. The profit function is $P(u) = -2u^2 + 50u - 300$, where $u$ is the number of units sold. Find the number of units that maximize profit.
#
# 7. You have 10 meters of string, and you need to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.
#
# 8. Find extremum of $f(x) = x^2 + 3x - 5$.
#
# 9. Find extremum of $f(x) =\frac{x^2+2x+1}{x-1}$.

# %% [markdown]
# 1. Compute derivatives of functions:
#    * $y(x) = -3x+3 = -3$
#    $$
#     (-3 * 1)x^(1-1) = -3x^0 = -3
#    $$
#    Constants equal to zero
#    * $y(x) = \pi x + \sin(1) = \pi$
#    $$
#     (\pi * 1)x^1-1 = \pi
#    $$
#    Sin(1) is a constant, and that equals to zero
#    * $y(x) = 4+\sin(2) = 0$
#    \
#    both are constants, so they equal to zero
#    * $y(x) = 2x^3 - 3x^2 + 8x - 9 = 6x^2 - 6x + 8$
#    $$
#     (2 * 3)x^(3-1) - (3 * 2)x^(2-1) + (8 * 1)x^0
#    $$
#    -9 is a constants, and constants equal to 0
#    * $y(x) = 6 x^{1/3} = 2 * \frac{3\sqrt{x}}{x}$
#    * $y(x) = \sqrt{x} = \frac{1}{2 * \sqrt{x}}$
#    * $y(x) = \cos(x) + \sin(x) = cos(x) - sin(x)$
#    \
#    cos(x) equals to 1 and sin(x) equals to 0
#    $$
#     1 + 0 = 1- 0
#    $$
#    $$
#     1 = 1
#    $$
#    * $y(x) = 2\sin(x) \cos(x) = 2 * (cos^2(x) - sin^2(y))$
#    * $y(x) = x\sin(x) = sin(x) + x*cos(x)$
#    * $y(x) = (x+1)(x+1) = 2x + 2$
#    $$
#     1x^2 + 2x + 1
#    $$
#    Now we use the power rule to find the Derivative
#    $$
#     (1 * 2)x^(2-1) + (2 * 1)x^(1 - 1)
#    $$
#    Constants equal to 0.
#    * $y(x) = \frac{x}{x+1} = \frac{1}{x^2 + 2x + 1}$
#    \
#    We use the quotient rule
#    $$
#     y'(x) = \frac{g'(x)h(x) - g(x)h'(x)}{h(x)^2}
#    $$
#    * $y(x) = (x+1)\exp(x) = 2e^x + xe^x$
#    * $y(x) = \sin(x^2) = 2x * cos(x^2)$
#    * $y(x) = \exp(-2x) = -2 * \exp(-2x)$
#    * $y(x) = \frac{1}{\sin(x+1)} = \frac{-cos(x + 1)}{sin^2(x + 1)}$
#    * $y(x) = \sqrt{2x+1} = \frac{1}{\sqrt{2x+1}}$
#
# GeoGebra: https://www.geogebra.org/calculator/z8hm7bsk
#
# 2. Prove:
#    - $\frac{d}{dx} (\ln(\sin(x))) = \cot(x)$
#    The Derivative of $ln(sin(x)) $ equals to $ \frac{cosx}{sinx}$ which is equal to the formula ot finding $cot(x)$($ \frac{cosx}{sinx}$)
#    \
#    $$
#    \begin{align*}
#     cos(x) = \frac{adj}{hyp} \\
#     sin(x) = \frac{opp}{hyp} \\ \\
#     \frac{cos(x)}{sin(x)} = \frac{\frac{adj}{\not{hyp}}}{\frac{opp}{\not{hyp}}}= \frac{adj}{opp} = cot(x)
#     \end{align*}
#    $$
# \
# Adjacent over the Hypotenius is Cotangent's formula in right-angle triangles
# \
# GeoGebra: https://www.geogebra.org/calculator/ayk7nzpx
#
# 3. For $f(x) = \cos(x)$, verify that $f''(x) = -f(x)$.
# \
# $$
# \begin{align*}
# f''(x) = -cos(x)
# \end{align*}
# $$
# The value of $f(x)$ with the second derivative ($f''(x)$) equals to -1 and since we have a given answer, we multiply it by -1
# \
# GeoGebra: https://www.geogebra.org/calculator/xbr9f8av
#
# 4. Using de l'Hospital's Rule, find the improper limits:
#    - $\displaystyle \lim_{x\to 0} \frac{\sin{x}}{x} = D(sinX) = cos(x);D(x) = 1;\frac{cos(x)}{1} = \frac{cos(0) = 1}{1} =1$
#    - $\displaystyle \lim_{x\to \infty} \frac{\ln x}{x} = D(lnx) = \frac{1}{x}; D(x) = 1; \frac{\frac{1}{x}}{1} = \frac{1}{x} = 0$
#    - $\displaystyle \lim_{x\to \infty} \frac{\exp(x)}{x} = D(e^x) = e^x; D(x) = 1;\frac{e^x}{1}$
#
# 5. In physics, the position of a particle is given by $x(t) = 3t^2 - 6t + 1$. Find the velocity $V(t)=x'(t)$ and acceleration $a(t)=V'(t)=x''(t)$ of the particle at time $t = 2$.
# \
# $$
# \begin{align*}
# x(t) = 3t^2 - 6t + 1
# \end{align*}
# $$
# Derivative of $x(t): 6t - 6$
# \
# $$
# V(t) = 6t -6
# $$
# To find the value of a(t) we have to find the derivative of $ V(T)$
# \
# $$
# a(t) = 6
# $$
# GeoGebra: https://www.geogebra.org/calculator/e4s6nd4p
#
#
# ## 22. Extremum
#
# 6. The profit function is $P(u) = -2u^2 + 50u - 300$, where $u$ is the number of units sold. Find the number of units that maximize profit.
# \
# We firstly have to find the derivative of P
# \
# $$
# P'(u) = -4u + 50
# $$
# To find the value of u, we'd have to make this equation equal to 0 (for the critical point, or to find the maximum value)
# \
# $$
# \begin{align*}
# -4u + 50 = 0 \\
# -4u = -50 \\
# u = \frac{50}{4} = 12.5
# \end{align*}
# $$
# GeoGebra: https://www.geogebra.org/calculator/t6xhpumw
#
# 7. You have 10 meters of string, and you need to use it to enclose the largest possible rectangular. Find the dimensions of the rectangle.
#
# 8. Find extremum of $f(x) = x^2 + 3x - 5$.
# \
# $$
# f'(x) = 2x + 3
# $$
# To find x, we'll have to set y equal to 0 (for the critical point, or to find the maximum value)
# \
# $$
# \begin{align*}
# 2x + 3 = 0 \\
# 2x = -3 \\
# x = \frac{-3}{2} = -1.5
# \end{align*}
# $$
# Now we just replace the values of the variables
# \
# $$
# f(\frac{-3}{2}) = \frac{9}{4} - \frac{9}{2} - 5 = \frac{-29}{4}
# $$
# GeoGebra: https://www.geogebra.org/calculator/cbtfd9u6
#
# 9. Find extremum of $f(x) =\frac{x^2+2x+1}{x-1}$.
# \
# We firstly have to find the derivative of this function (Quitient rule)
# $$
# f'(x) = \frac{g'(x)h(x) - g(x)h'(x)}{h(x)^2}
# $$
# $$
# f'(x) = \frac{(x + 1)^2}{(x-1)} = \frac{(2(x + 1) * (x-1)) - ((x + 1)^2)}{(x - 1)^2} = \frac{x^2 - 2x - 3}{(x - 1)^2}
# $$
# $$
# f'(x) = \frac{(x - 3)(x + 1)}{(x - 1)^2} = 0
# $$
# We have 2 values that can get us a 0 ($x = 3; x = -1$)
# \
# $$
# f(x) = \frac{9 + 6 + 1}{2} = 8
# $$
# $$
# f(x) = \frac{1 -2 + 1}{-2} = 0
# $$
